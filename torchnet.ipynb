# %%
import numpy as np
import torch

# %%
from agents.pytorch import Model

# %%
model = Model()

# %%
m.load("models/test.pth")
# Out:
# Model(
#   (net): Sequential(
#     (0): Sequential(
#       (0): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU()
#       (2): Dropout(p=0.1, inplace=False)
#       (3): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (4): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#     )
#     (1): Sequential(
#       (0): Conv2d(16, 64, kernel_size=(3, 3), stride=(1, 1), padding=(0, 1))
#       (1): ReLU()
#       (2): Dropout(p=0.1, inplace=False)
#       (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (4): MaxPool2d(kernel_size=(3, 3), stride=(3, 3), padding=0, dilation=1, ceil_mode=False)
#     )
#     (2): Sequential(
#       (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(0, 1))
#       (1): ReLU()
#       (2): Dropout(p=0.1, inplace=False)
# ...

# %%
inp = torch.from_numpy(np.random.random((1, 3, 280, 120))).float()

# %%
m(inp)
# Out:
# tensor([[-1.9242, -0.9193, -0.1492, -0.0088,  2.7347]],
#        grad_fn=<AddmmBackward0>)

# %%
m.save('models/test.pth')

# %%
b = Model()

# %%
b.load('models/test.pth')

# %%
b(inp)
